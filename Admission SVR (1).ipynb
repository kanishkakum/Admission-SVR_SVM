# %% [markdown]
# # Admission Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# # Data Ingestion

# %%
data=pd.read_csv('https://raw.githubusercontent.com/srinivasav22/Graduate-Admission-Prediction/master/Admission_Predict_Ver1.1.csv')

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
data.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# 495         1              0.87
# 496         1              0.96
# 497         1              0.93
# 498         0              0.73
# 499         0              0.84

# %% [markdown]
# # Information about data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
data.shape
# Out:
# (500, 9)

# %% [markdown]
# Admission dataset has 500 rows and 9 features. 5 features has datatype of integer and rest has float

# %%
#checking the features of dataset
data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %% [markdown]
# **From above we can see that there are unnecessary spaces, So we need to remove those extra spaces.**

# %%
#removing spaces from feature
data.columns = data.columns.str.strip()

# %%
## checking the spaces
data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %% [markdown]
# **Describing the dataset**

# %%
data.describe().T
# Out:
#                    count       mean         std     min       25%     50%  \
# Serial No.         500.0  250.50000  144.481833    1.00  125.7500  250.50
# GRE Score          500.0  316.47200   11.295148  290.00  308.0000  317.00
# TOEFL Score        500.0  107.19200    6.081868   92.00  103.0000  107.00
# University Rating  500.0    3.11400    1.143512    1.00    2.0000    3.00
# SOP                500.0    3.37400    0.991004    1.00    2.5000    3.50
# LOR                500.0    3.48400    0.925450    1.00    3.0000    3.50
# CGPA               500.0    8.57644    0.604813    6.80    8.1275    8.56
# Research           500.0    0.56000    0.496884    0.00    0.0000    1.00
# Chance of Admit    500.0    0.72174    0.141140    0.34    0.6300    0.72
#
#                       75%     max
# Serial No.         375.25  500.00
# GRE Score          325.00  340.00
# TOEFL Score        112.00  120.00
# University Rating    4.00    5.00
# SOP                  4.00    5.00
# ...
